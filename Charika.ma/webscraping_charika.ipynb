# %%
import pandas as pd

# %%
data=pd.read_csv('Output/infos_entreprises_final.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1660 entries, 0 to 1659
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Nom de l'entreprise        1656 non-null   object
#  1   Activite                   1655 non-null   object
#  2   Adresse                    1641 non-null   object
#  3   Ville                      1641 non-null   object
#  4   Coordonnees geographiques  1653 non-null   object
#  5   RC                         1654 non-null   object
#  6   Tribunal                   1656 non-null   object
#  7   ICE                        343 non-null    float64
#  8   Forme Juridique            1655 non-null   object
#  9   Capital                    1656 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 129.8+ KB

# %%
data.describe(include='all')
# Out:
#        Nom de l'entreprise                            Activite  \
# count                 1656                                1655
# unique                1656                                1452
# top      ORNELLA (ORNELLA)   marchand effectuant import-export
# freq                     1                                  28
# mean                   NaN                                 NaN
# std                    NaN                                 NaN
# min                    NaN                                 NaN
# 25%                    NaN                                 NaN
# 50%                    NaN                                 NaN
# 75%                    NaN                                 NaN
# max                    NaN                                 NaN
#
#                  Adresse       Ville                Coordonnees geographiques  \
# count               1641        1641                                     1653
# ...

# %%
data
# Out:
#                                     Nom de l'entreprise  \
# 0                                     ORNELLA (ORNELLA)
# 1                             PYROCARBONE (STE ANONYME)
# 2                                   SOCOF (STE) (SOCOF)
# 3                                    BARSAL (TRANSPORT)
# 4     SOCIETE D'EQUIPEMENT ET CONSTRUCTION EL AHMADI...
# ...                                                 ...
# 1655                                         AL INIITAK
# 1656                                EXPERT SOFT SERVICE
# 1657                                      STE BAYT NORD
# 1658                  EL MASSI ET ALI LABO-PHOTOS BOSNA
# 1659  MAROCAINE DES PRODUITS FRAIS DE LA MER (STE) (...
#
#                                                Activite  \
# 0      la confection de tous vetements d'hommes de f...
# 1      toutes operations commerciales industrielles ...
# 2                                            confection
# 3                             transport de marchandises
# ...
